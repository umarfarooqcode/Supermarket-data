# %% [markdown]
# supermarket_sales.csv

# %%
import pandas as pd
import numpy as np

# %%
supermarket_sales_df = pd.read_csv(r"C:\Users\user\Desktop\supermarket_sales\supermarket_sales.csv")

# %%
supermarket_sales_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
supermarket_sales_df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
supermarket_sales_df.info
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
supermarket_sales_df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
type(supermarket_sales_df)
# Out:
# pandas.core.frame.DataFrame

# %%
supermarket_sales_null_df = supermarket_sales_df.isnull().sum()
supermarket_sales_null_df
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
remove_duplicate_value=supermarket_sales_df.drop_duplicates(inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(supermarket_sales_df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
supermarket_sales_df['Total_Revenue'] = supermarket_sales_df['Quantity'] * supermarket_sales_df['Unit price']

# %%
total_revenue_per_category = supermarket_sales_df.groupby('Product line')['Total_Revenue'].sum().reset_index()
total_revenue_per_category
# Out:
#              Product line  Total_Revenue
# 0  Electronic accessories       51750.03
# 1     Fashion accessories       51719.90
# 2      Food and beverages       53471.28
# 3       Health and beauty       46851.18
# 4      Home and lifestyle       51297.06
# 5       Sports and travel       52497.93

# %%
most_profitable_categories = total_revenue_per_category.sort_values(by='Total_Revenue', ascending=False)
most_profitable_categories
# Out:
#              Product line  Total_Revenue
# 2      Food and beverages       53471.28
# 5       Sports and travel       52497.93
# 0  Electronic accessories       51750.03
# 1     Fashion accessories       51719.90
# 4      Home and lifestyle       51297.06
# 3       Health and beauty       46851.18

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='Total_Revenue', y='Product line', data=most_profitable_categories)
plt.title('Total Revenue per Product Category')
plt.xlabel('Total Revenue')
plt.ylabel('Product Category')
plt.show()

# %% [markdown]
# Related to ensuring correct data types for columns, specifically for converting dates and times to datetime format, recognizing categorical variables, and ensuring numerical variables are in appropriate numeric formats, follow these steps using pandas in Python:

# %%
supermarket_sales_df['Date'] = pd.to_datetime(supermarket_sales_df['Date'])

# %%
print(supermarket_sales_df.columns)
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Total_Revenue'],
#       dtype='object')

# %%
supermarket_sales_df['Product line'] = supermarket_sales_df['Product line'].astype('category')

# %%
supermarket_sales_df['Unit price'] = supermarket_sales_df['Unit price'].astype(float)

# %%
print(supermarket_sales_df.dtypes)
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                     category
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# Total_Revenue                     float64
# dtype: object

# %%
import pandas as pd

# Load the dataset
supermarket_sales_df = pd.read_csv(r"C:\Users\user\Desktop\supermarket_sales\supermarket_sales.csv")

# Convert date and time columns
supermarket_sales_df['Date'] = pd.to_datetime(supermarket_sales_df['Date'])
supermarket_sales_df['Date'] = pd.to_datetime(supermarket_sales_df['Date'])

# Convert categorical columns
supermarket_sales_df['Product line'] = supermarket_sales_df['Product line'].astype('category')
supermarket_sales_df['Customer type'] = supermarket_sales_df['Customer type'].astype('category')


# Convert numerical columns
supermarket_sales_df['Total'] = supermarket_sales_df['Total'].astype(float)
supermarket_sales_df['Quantity'] = supermarket_sales_df['Quantity'].astype(int)

# Verify data types
print(supermarket_sales_df.dtypes)
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                    category
# Gender                             object
# Product line                     category
# Unit price                        float64
# Quantity                            int32
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
# First, ensure both 'Date' and 'Time' columns are in string format and combine them
supermarket_sales_df['Datetime'] = pd.to_datetime(supermarket_sales_df['Date'].astype(str) + ' ' + supermarket_sales_df['Time'].astype(str))

# Now you can extract the desired information
supermarket_sales_df['Hour'] = supermarket_sales_df['Datetime'].dt.hour
supermarket_sales_df['DayOfWeek'] = supermarket_sales_df['Datetime'].dt.day_name()  # This gives you the name of the day
supermarket_sales_df['Month'] = supermarket_sales_df['Datetime'].dt.month

# %%
sales_by_hour = supermarket_sales_df.groupby('Hour')['Total'].sum().reset_index()

# Assuming you're using matplotlib and seaborn for visualization
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='Hour', y='Total', data=sales_by_hour)
plt.title('Sales by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# Location-wise Sales Performance: Bar charts comparing total sales among different supermarket locations.

# %%
import pandas as pd

# Assuming df is your DataFrame
total_sales_by_location = supermarket_sales_df.groupby('City')['Total'].sum().reset_index()

# %%
total_sales_by_location_sorted = total_sales_by_location.sort_values('Total', ascending=False).reset_index(drop=True)
total_sales_by_location_sorted
# Out:
#         City        Total
# 0  Naypyitaw  110568.7065
# 1     Yangon  106200.3705
# 2   Mandalay  106197.6720

# %%
plt.figure(figsize=(10, 6));
sns.barplot(x='Total', y='City', data=total_sales_by_location_sorted, palette='viridis');
plt.title('Location-wise Sales Performance');
plt.xlabel('Total Sales');
plt.ylabel('Location');
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6732\1665631880.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Total', y='City', data=total_sales_by_location_sorted, palette='viridis');

# %%
# Calculate total sales by location
total_sales_by_location = supermarket_sales_df.groupby('City')['Total'].sum().reset_index();

# Sort locations by total sales
total_sales_by_location_sorted = total_sales_by_location.sort_values('Total', ascending=False).reset_index(drop=True);

# Visualize with a bar chart
plt.figure(figsize=(10, 6));
sns.barplot(x='Total', y='City', data=total_sales_by_location_sorted, palette='viridis');
plt.title('Location-wise Sales Performance');
plt.xlabel('Total Sales');
plt.ylabel('Location');
plt.show();
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6732\230133974.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Total', y='City', data=total_sales_by_location_sorted, palette='viridis');

# %% [markdown]
# A heatmap or bar chart showing the quantity of products sold, potentially broken down by category or location.

# %%
# Aggregate quantity sold by category and location
quantity_by_product_line_and_city = supermarket_sales_df.groupby(['Product line', 'City'])['Quantity'].sum().unstack(fill_value=0);
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6732\1934527238.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   quantity_by_product_line_and_city = supermarket_sales_df.groupby(['Product line', 'City'])['Quantity'].sum().unstack(fill_value=0);

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(quantity_by_product_line_and_city, annot=True, cmap='YlGnBu', fmt='g')
plt.title('Quantity of Products Sold by Category and Location')
plt.xlabel('City')
plt.ylabel('Product line')
plt.show()

# %%
# Melt the DataFrame to long format for bar plotting
melted_data = quantity_by_product_line_and_city.reset_index().melt(id_vars=['Product line'], var_name='City', value_name='Quantity')

plt.figure(figsize=(14, 7))
sns.barplot(x='Product line', y='Quantity', hue='City', data=melted_data, palette='viridis')
plt.title('Quantity of Products Sold by Product Line and City')
plt.xticks(rotation=45)
plt.show()
